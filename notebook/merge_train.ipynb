# %%
import pandas as pd
import numpy as np
import re
from functools import partial
from glob import glob

# %%
paths = glob('../train/*')
train_dfs = []
for path in paths:
    train_df = pd.read_csv(path)
    train_dfs.append(train_df)
    
train_df = pd.concat(train_dfs)
train_df.reset_index(drop=True, inplace=True)
# Out:
# /home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_df.to_csv("../input/train.csv", index=False)

# %%
train_df
# Out:
#              ID        種類  地域  市区町村コード 都道府県名 市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）  \
# 0       8033256  中古マンション等 NaN     8203   茨城県   土浦市   川口     土浦        11
# 1       8041376  中古マンション等 NaN     8220   茨城県  つくば市   並木    つくば   30分?60分
# 2       8003595  中古マンション等 NaN     8201   茨城県   水戸市   南町     水戸        13
# 3       8000968  中古マンション等 NaN     8201   茨城県   水戸市   大町     水戸        16
# 4       8044248  中古マンション等 NaN     8220   茨城県  つくば市   並木    つくば   30分?60分
# ...         ...       ...  ..      ...   ...   ...  ...    ...       ...
# 662794  3005573  中古マンション等 NaN     3201   岩手県   盛岡市   東山     盛岡   30分?60分
# 662795  3005930  中古マンション等 NaN     3201   岩手県   盛岡市   茶畑     盛岡   30分?60分
# 662796  3015560  中古マンション等 NaN     3201   岩手県   盛岡市  材木町     盛岡         8
# 662797  3003542  中古マンション等 NaN     3201   岩手県   盛岡市  中央通     盛岡         8
# 662798  3004535  中古マンション等 NaN     3201   岩手県   盛岡市  紺屋町     盛岡        26
#
#          間取り  ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）          都市計画 建ぺい率（％） 容積率（％）  \
# 0       ４ＬＤＫ  ...     NaN      NaN         NaN       第２種住居地域    60.0  200.0
# 1       ３ＬＤＫ  ...     NaN      NaN         NaN  第１種中高層住居専用地域    60.0  200.0
# 2       １ＬＤＫ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 3       ２ＬＤＫ  ...     NaN      NaN         NaN        近隣商業地域    80.0  400.0
# 4       ３ＬＤＫ  ...     NaN      NaN         NaN  第１種中高層住居専用地域    60.0  200.0
# ...      ...  ...     ...      ...         ...           ...     ...    ...
# 662794  ２ＬＤＫ  ...     NaN      NaN         NaN  第２種中高層住居専用地域    60.0  200.0
# 662795  ２ＬＤＫ  ...     NaN      NaN         NaN       第１種住居地域    60.0  200.0
# 662796    １Ｋ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 662797   ２ＤＫ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 662798    １Ｋ  ...     NaN      NaN         NaN       第１種住居地域    80.0  400.0
#
#               取引時点   改装  取引の事情等  取引価格（総額）_log
# 0       2009年第４四半期  未改装     NaN      7.255273
# 1       2010年第３四半期  改装済     NaN      7.278754
# 2       2014年第４四半期  未改装     NaN      6.633468
# 3       2019年第２四半期  未改装     NaN      7.204120
# 4       2017年第１四半期  未改装     NaN      7.301030
# ...            ...  ...     ...           ...
# 662794  2017年第２四半期  改装済     NaN      6.949390
# 662795  2013年第２四半期  未改装  調停・競売等      6.799341
# 662796  2009年第２四半期  未改装  調停・競売等      6.255273
# 662797  2017年第３四半期  未改装     NaN      6.812913
# 662798  2013年第３四半期  未改装     NaN      6.278754
#
# [662799 rows x 28 columns]

# %%
pd.read_csv("../input/train.csv")
# Out:
# /home/kengo-fujii/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              ID        種類  地域  市区町村コード 都道府県名 市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）  \
# 0       8033256  中古マンション等 NaN     8203   茨城県   土浦市   川口     土浦        11
# 1       8041376  中古マンション等 NaN     8220   茨城県  つくば市   並木    つくば   30分?60分
# 2       8003595  中古マンション等 NaN     8201   茨城県   水戸市   南町     水戸        13
# 3       8000968  中古マンション等 NaN     8201   茨城県   水戸市   大町     水戸        16
# 4       8044248  中古マンション等 NaN     8220   茨城県  つくば市   並木    つくば   30分?60分
# ...         ...       ...  ..      ...   ...   ...  ...    ...       ...
# 662794  3005573  中古マンション等 NaN     3201   岩手県   盛岡市   東山     盛岡   30分?60分
# 662795  3005930  中古マンション等 NaN     3201   岩手県   盛岡市   茶畑     盛岡   30分?60分
# 662796  3015560  中古マンション等 NaN     3201   岩手県   盛岡市  材木町     盛岡         8
# 662797  3003542  中古マンション等 NaN     3201   岩手県   盛岡市  中央通     盛岡         8
# 662798  3004535  中古マンション等 NaN     3201   岩手県   盛岡市  紺屋町     盛岡        26
#
#          間取り  ... 前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）          都市計画 建ぺい率（％） 容積率（％）  \
# 0       ４ＬＤＫ  ...     NaN      NaN         NaN       第２種住居地域    60.0  200.0
# 1       ３ＬＤＫ  ...     NaN      NaN         NaN  第１種中高層住居専用地域    60.0  200.0
# 2       １ＬＤＫ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 3       ２ＬＤＫ  ...     NaN      NaN         NaN        近隣商業地域    80.0  400.0
# 4       ３ＬＤＫ  ...     NaN      NaN         NaN  第１種中高層住居専用地域    60.0  200.0
# ...      ...  ...     ...      ...         ...           ...     ...    ...
# 662794  ２ＬＤＫ  ...     NaN      NaN         NaN  第２種中高層住居専用地域    60.0  200.0
# 662795  ２ＬＤＫ  ...     NaN      NaN         NaN       第１種住居地域    60.0  200.0
# 662796    １Ｋ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 662797   ２ＤＫ  ...     NaN      NaN         NaN          商業地域    80.0  400.0
# 662798    １Ｋ  ...     NaN      NaN         NaN       第１種住居地域    80.0  400.0
#
#               取引時点   改装  取引の事情等  取引価格（総額）_log
# 0       2009年第４四半期  未改装     NaN      7.255273
# 1       2010年第３四半期  改装済     NaN      7.278754
# 2       2014年第４四半期  未改装     NaN      6.633468
# 3       2019年第２四半期  未改装     NaN      7.204120
# 4       2017年第１四半期  未改装     NaN      7.301030
# ...            ...  ...     ...           ...
# 662794  2017年第２四半期  改装済     NaN      6.949390
# 662795  2013年第２四半期  未改装  調停・競売等      6.799341
# 662796  2009年第２四半期  未改装  調停・競売等      6.255273
# 662797  2017年第３四半期  未改装     NaN      6.812913
# 662798  2013年第３四半期  未改装     NaN      6.278754
#
# [662799 rows x 28 columns]
